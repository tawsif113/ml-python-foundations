# %% [markdown]
# <a href="https://colab.research.google.com/github/tawsif113/ml-python-foundations/blob/main/week1/Python_Core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## VARIABLES, TYPES, COLLECTIONS

# %%
name = "Arima"
age = 35
cgpa = 3.59
is_engineer = True
print(name, type(name))
# Out:
# Arima <class 'str'>

# %%
print(age, type(age))
print(cgpa, type(cgpa))
print(is_engineer, type(is_engineer))
# Out:
# 35 <class 'int'>
# 3.59 <class 'float'>
# True <class 'bool'>

# %%
numbers = [1,2,3,4,5]
coords = (23.7, 90.4)
unique_nums = {1,2,2,3,4}
student = {"name":"Arima",
           "age": 25,
           "cgpa": 3.59,
           "is_engineer": True,
           "role":"Engineer"
          }

# %%
print(numbers, type(numbers))
print(coords, type(coords))
print(unique_nums, type(unique_nums))
print(student, type(student))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>
# (23.7, 90.4) <class 'tuple'>
# {1, 2, 3, 4} <class 'set'>
# {'name': 'Arima', 'age': 25, 'cgpa': 3.59, 'is_engineer': True, 'role': 'Engineer'} <class 'dict'>

# %%
print(student["name"], type(student["name"]))
# Out:
# Arima <class 'str'>

# %% [markdown]
# ## CONDITIONALS

# %%
x = 7
if x%2 == 0:
  print("Even")
else:
  print("NOT EVEN")
# Out:
# NOT EVEN

# %% [markdown]
# ##LOOPS

# %%
for i in numbers:
  print(i,end=", ")
# Out:
# 1, 2, 3, 4, 5,

# %%
vowels = {'A','E', 'I', 'O', 'U', 'Y'}

# %%
print(f"Hi My Name is {name}\nAnd My Cgpa is {cgpa}\nAnd I Am {"An" if student['role'][0] in vowels else "A"} {student['role']}")
# Out:
# Hi My Name is Arima
# And My Cgpa is 3.59
# And I Am An Engineer

# %%
count = 1
itr = 0
while count <= 5:
  itr+=1
  count+=1
  print(f"Iteration: {itr}, Count: {count}")
# Out:
# Iteration: 1, Count: 2
# Iteration: 2, Count: 3
# Iteration: 3, Count: 4
# Iteration: 4, Count: 5
# Iteration: 5, Count: 6

# %%
squares = [i*i for i in numbers]
print(squares,sep=",",end="...")
# Out:
# [1, 4, 9, 16, 25]...

# %% [markdown]
# ##FUNCTIONS

# %%
class Student:
  def __init__(self, name, age, cgpa):
    self.name = name
    self.age = age
    self.cgpa = cgpa
  def display_info(self):
    return f"Name: {self.name}, Age: {self.age}, CGPA: {self.cgpa}"

# %%
s1 = Student(student["name"], student["age"], student["cgpa"])
print(s1.display_info())
# Out:
# Name: Arima, Age: 25, CGPA: 3.59

# %% [markdown]
# ##PRACTICE TASKS

# %%
def is_even(num):
  return num%2 == 0

# %%
print(is_even(5))
# Out:
# False

# %%
def clean_up_sentence(sentence):
  sentence = sentence.lower()
  sentence = sentence.replace(".","")
  sentence = sentence.replace(",","")
  sentence = sentence.replace("!","")
  sentence = sentence.replace("?","")
  return sentence

# %%
def word_frequency(sentence):
  sentence = clean_up_sentence(sentence)
  words = sentence.lower().split()
  freq = {}
  for word in words:
    if word in freq:
      freq[word]+=1
    else:
      freq[word]=1
  sorted_freq = dict(sorted(freq.items(),key= lambda item:item[1], reverse=True))
  return sorted_freq
sentence = input("Enter a sentence: ")
print(word_frequency(sentence))
# Out:
# Enter a sentence: Hello bro, how do u do do me did
# {'do': 3, 'hello': 1, 'bro': 1, 'how': 1, 'u': 1, 'me': 1, 'did': 1}

# %%
word_frequency("Hello world How do u do")
# Out:
# {'do': 2, 'hello': 1, 'world': 1, 'how': 1, 'u': 1}

# %%
def find_max(numbers):
  max = -1e9
  for i in numbers:
    if i > max:
      max = i
  return max
numbers = input("Enter a list of numbers: ").split(",")
numbers = [int(i) for i in numbers]
print(find_max(numbers))
# Out:
# Enter a list of numbers: 1,2,300
# 300
